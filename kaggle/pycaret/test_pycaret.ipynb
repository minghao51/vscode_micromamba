# %%
import pandas as pd
import numpy as np

# %%
# loading sample dataset
from pycaret.datasets import get_data
data = get_data('juice')

# init setup
from pycaret.classification import ClassificationExperiment
s = ClassificationExperiment()
s.setup(data, target = 'Purchase', session_id = 123)

# model training and selection
best = s.compare_models()

# evaluate trained model
s.evaluate_model(best)

# predict on hold-out/test set
pred_holdout = s.predict_model(best)

# predict on new data
new_data = data.copy().drop('Purchase', axis = 1)
predictions = s.predict_model(best, data = new_data)

# save model
s.save_model(best, 'best_pipeline')
# Out:
#    Id Purchase  WeekofPurchase  StoreID  PriceCH  PriceMM  DiscCH  DiscMM
# 0   1       CH             237        1     1.75     1.99    0.00     0.0  \
# 1   2       CH             239        1     1.75     1.99    0.00     0.3
# 2   3       CH             245        1     1.86     2.09    0.17     0.0
# 3   4       MM             227        1     1.69     1.69    0.00     0.0
# 4   5       CH             228        7     1.69     1.69    0.00     0.0
#
#    SpecialCH  SpecialMM   LoyalCH  SalePriceMM  SalePriceCH  PriceDiff Store7
# 0          0          0  0.500000         1.99         1.75       0.24     No  \
# 1          0          1  0.600000         1.69         1.75      -0.06     No
# 2          0          0  0.680000         2.09         1.69       0.40     No
# 3          0          0  0.400000         1.69         1.69       0.00     No
# 4          0          0  0.956535         1.69         1.69       0.00    Yes
#
#    PctDiscMM  PctDiscCH  ListPriceDiff  STORE
# 0   0.000000   0.000000           0.24      1
# 1   0.150754   0.000000           0.24      1
# 2   0.000000   0.091398           0.23      1
# 3   0.000000   0.000000           0.00      1
# 4   0.000000   0.000000           0.00      0
# <style type="text/css">
# #T_d032d_row11_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_d032d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d032d_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_d032d_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d032d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d032d_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_d032d_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_d032d_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_d032d_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_d032d_row1_col1" class="data row1 col1" >Purchase</td>
#     </tr>
#     <tr>
#       <th id="T_d032d_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_d032d_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_d032d_row2_col1" class="data row2 col1" >Binary</td>
#     </tr>
#     <tr>
#       <th id="T_d032d_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_d032d_row3_col0" class="data row3 col0" >Target mapping</td>
#       <td id="T_d032d_row3_col1" class="data row3 col1" >CH: 0, MM: 1</td>
#     </tr>
#     <tr>
#       <th id="T_d032d_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_d032d_row4_col0" class="data row4 col0" >Original data shape</td>
#       <td id="T_d032d_row4_col1" class="data row4 col1" >(1070, 19)</td>
#     </tr>
#     <tr>
#       <th id="T_d032d_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_d032d_row5_col0" class="data row5 col0" >Transformed data shape</td>
#       <td id="T_d032d_row5_col1" class="data row5 col1" >(1070, 19)</td>
#     </tr>
#     <tr>
#       <th id="T_d032d_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_d032d_row6_col0" class="data row6 col0" >Transformed train set shape</td>
#       <td id="T_d032d_row6_col1" class="data row6 col1" >(749, 19)</td>
#     </tr>
#     <tr>
#       <th id="T_d032d_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_d032d_row7_col0" class="data row7 col0" >Transformed test set shape</td>
#       <td id="T_d032d_row7_col1" class="data row7 col1" >(321, 19)</td>
#     </tr>
#     <tr>
#       <th id="T_d032d_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_d032d_row8_col0" class="data row8 col0" >Ordinal features</td>
#       <td id="T_d032d_row8_col1" class="data row8 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_d032d_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_d032d_row9_col0" class="data row9 col0" >Numeric features</td>
#       <td id="T_d032d_row9_col1" class="data row9 col1" >17</td>
#     </tr>
#     <tr>
#       <th id="T_d032d_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_d032d_row10_col0" class="data row10 col0" >Categorical features</td>
#       <td id="T_d032d_row10_col1" class="data row10 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_d032d_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_d032d_row11_col0" class="data row11 col0" >Preprocess</td>
#       <td id="T_d032d_row11_col1" class="data row11 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_d032d_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_d032d_row12_col0" class="data row12 col0" >Imputation type</td>
#       <td id="T_d032d_row12_col1" class="data row12 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_d032d_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_d032d_row13_col0" class="data row13 col0" >Numeric imputation</td>
#       <td id="T_d032d_row13_col1" class="data row13 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_d032d_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_d032d_row14_col0" class="data row14 col0" >Categorical imputation</td>
#       <td id="T_d032d_row14_col1" class="data row14 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_d032d_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_d032d_row15_col0" class="data row15 col0" >Maximum one-hot encoding</td>
#       <td id="T_d032d_row15_col1" class="data row15 col1" >25</td>
#     </tr>
#     <tr>
#       <th id="T_d032d_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_d032d_row16_col0" class="data row16 col0" >Encoding method</td>
#       <td id="T_d032d_row16_col1" class="data row16 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_d032d_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_d032d_row17_col0" class="data row17 col0" >Fold Generator</td>
#       <td id="T_d032d_row17_col1" class="data row17 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_d032d_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_d032d_row18_col0" class="data row18 col0" >Fold Number</td>
#       <td id="T_d032d_row18_col1" class="data row18 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_d032d_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_d032d_row19_col0" class="data row19 col0" >CPU Jobs</td>
#       <td id="T_d032d_row19_col1" class="data row19 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_d032d_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_d032d_row20_col0" class="data row20 col0" >Use GPU</td>
#       <td id="T_d032d_row20_col1" class="data row20 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_d032d_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_d032d_row21_col0" class="data row21 col0" >Log Experiment</td>
#       <td id="T_d032d_row21_col1" class="data row21 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_d032d_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_d032d_row22_col0" class="data row22 col0" >Experiment Name</td>
#       <td id="T_d032d_row22_col1" class="data row22 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_d032d_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_d032d_row23_col0" class="data row23 col0" >USI</td>
#       <td id="T_d032d_row23_col1" class="data row23 col1" >9986</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_45b58 th {
#   text-align: left;
# }
# #T_45b58_row0_col0, #T_45b58_row0_col4, #T_45b58_row1_col0, #T_45b58_row1_col1, #T_45b58_row1_col2, #T_45b58_row1_col3, #T_45b58_row1_col5, #T_45b58_row1_col6, #T_45b58_row1_col7, #T_45b58_row2_col0, #T_45b58_row2_col1, #T_45b58_row2_col2, #T_45b58_row2_col3, #T_45b58_row2_col4, #T_45b58_row2_col5, #T_45b58_row2_col6, #T_45b58_row2_col7, #T_45b58_row3_col0, #T_45b58_row3_col1, #T_45b58_row3_col2, #T_45b58_row3_col3, #T_45b58_row3_col4, #T_45b58_row3_col5, #T_45b58_row3_col6, #T_45b58_row3_col7, #T_45b58_row4_col0, #T_45b58_row4_col1, #T_45b58_row4_col2, #T_45b58_row4_col3, #T_45b58_row4_col4, #T_45b58_row4_col5, #T_45b58_row4_col6, #T_45b58_row4_col7, #T_45b58_row5_col0, #T_45b58_row5_col1, #T_45b58_row5_col2, #T_45b58_row5_col3, #T_45b58_row5_col4, #T_45b58_row5_col5, #T_45b58_row5_col6, #T_45b58_row5_col7, #T_45b58_row6_col0, #T_45b58_row6_col1, #T_45b58_row6_col2, #T_45b58_row6_col3, #T_45b58_row6_col4, #T_45b58_row6_col5, #T_45b58_row6_col6, #T_45b58_row6_col7, #T_45b58_row7_col0, #T_45b58_row7_col1, #T_45b58_row7_col2, #T_45b58_row7_col3, #T_45b58_row7_col4, #T_45b58_row7_col5, #T_45b58_row7_col6, #T_45b58_row7_col7, #T_45b58_row8_col0, #T_45b58_row8_col1, #T_45b58_row8_col2, #T_45b58_row8_col3, #T_45b58_row8_col4, #T_45b58_row8_col5, #T_45b58_row8_col6, #T_45b58_row8_col7, #T_45b58_row9_col0, #T_45b58_row9_col1, #T_45b58_row9_col2, #T_45b58_row9_col3, #T_45b58_row9_col4, #T_45b58_row9_col5, #T_45b58_row9_col6, #T_45b58_row9_col7, #T_45b58_row10_col0, #T_45b58_row10_col1, #T_45b58_row10_col2, #T_45b58_row10_col3, #T_45b58_row10_col4, #T_45b58_row10_col5, #T_45b58_row10_col6, #T_45b58_row10_col7, #T_45b58_row11_col0, #T_45b58_row11_col1, #T_45b58_row11_col2, #T_45b58_row11_col3, #T_45b58_row11_col4, #T_45b58_row11_col5, #T_45b58_row11_col6, #T_45b58_row11_col7, #T_45b58_row12_col0, #T_45b58_row12_col1, #T_45b58_row12_col2, #T_45b58_row12_col3, #T_45b58_row12_col4, #T_45b58_row12_col5, #T_45b58_row12_col6, #T_45b58_row12_col7, #T_45b58_row13_col0, #T_45b58_row13_col1, #T_45b58_row13_col2, #T_45b58_row13_col3, #T_45b58_row13_col4, #T_45b58_row13_col5, #T_45b58_row13_col6, #T_45b58_row13_col7, #T_45b58_row14_col0, #T_45b58_row14_col1, #T_45b58_row14_col2, #T_45b58_row14_col3, #T_45b58_row14_col4, #T_45b58_row14_col5, #T_45b58_row14_col6, #T_45b58_row14_col7, #T_45b58_row15_col0, #T_45b58_row15_col1, #T_45b58_row15_col2, #T_45b58_row15_col3, #T_45b58_row15_col4, #T_45b58_row15_col5, #T_45b58_row15_col6, #T_45b58_row15_col7 {
#   text-align: left;
# }
# #T_45b58_row0_col1, #T_45b58_row0_col2, #T_45b58_row0_col3, #T_45b58_row0_col5, #T_45b58_row0_col6, #T_45b58_row0_col7, #T_45b58_row1_col4 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_45b58_row0_col8, #T_45b58_row1_col8, #T_45b58_row3_col8, #T_45b58_row4_col8, #T_45b58_row5_col8, #T_45b58_row6_col8, #T_45b58_row7_col8, #T_45b58_row8_col8, #T_45b58_row9_col8, #T_45b58_row10_col8, #T_45b58_row11_col8, #T_45b58_row12_col8, #T_45b58_row13_col8, #T_45b58_row14_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_45b58_row2_col8, #T_45b58_row15_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_45b58">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_45b58_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_45b58_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_45b58_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_45b58_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_45b58_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_45b58_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_45b58_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_45b58_level0_col7" class="col_heading level0 col7" >MCC</th>
#       <th id="T_45b58_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_45b58_level0_row0" class="row_heading level0 row0" >lda</th>
#       <td id="T_45b58_row0_col0" class="data row0 col0" >Linear Discriminant Analysis</td>
#       <td id="T_45b58_row0_col1" class="data row0 col1" >0.8278</td>
#       <td id="T_45b58_row0_col2" class="data row0 col2" >0.8941</td>
#       <td id="T_45b58_row0_col3" class="data row0 col3" >0.7637</td>
#       <td id="T_45b58_row0_col4" class="data row0 col4" >0.7909</td>
#       <td id="T_45b58_row0_col5" class="data row0 col5" >0.7740</td>
#       <td id="T_45b58_row0_col6" class="data row0 col6" >0.6354</td>
#       <td id="T_45b58_row0_col7" class="data row0 col7" >0.6388</td>
#       <td id="T_45b58_row0_col8" class="data row0 col8" >0.0250</td>
#     </tr>
#     <tr>
#       <th id="T_45b58_level0_row1" class="row_heading level0 row1" >lr</th>
#       <td id="T_45b58_row1_col0" class="data row1 col0" >Logistic Regression</td>
#       <td id="T_45b58_row1_col1" class="data row1 col1" >0.8171</td>
#       <td id="T_45b58_row1_col2" class="data row1 col2" >0.8932</td>
#       <td id="T_45b58_row1_col3" class="data row1 col3" >0.7224</td>
#       <td id="T_45b58_row1_col4" class="data row1 col4" >0.7952</td>
#       <td id="T_45b58_row1_col5" class="data row1 col5" >0.7540</td>
#       <td id="T_45b58_row1_col6" class="data row1 col6" >0.6094</td>
#       <td id="T_45b58_row1_col7" class="data row1 col7" >0.6140</td>
#       <td id="T_45b58_row1_col8" class="data row1 col8" >1.4860</td>
#     </tr>
#     <tr>
#       <th id="T_45b58_level0_row2" class="row_heading level0 row2" >ridge</th>
#       <td id="T_45b58_row2_col0" class="data row2 col0" >Ridge Classifier</td>
#       <td id="T_45b58_row2_col1" class="data row2 col1" >0.8158</td>
#       <td id="T_45b58_row2_col2" class="data row2 col2" >0.0000</td>
#       <td id="T_45b58_row2_col3" class="data row2 col3" >0.7431</td>
#       <td id="T_45b58_row2_col4" class="data row2 col4" >0.7807</td>
#       <td id="T_45b58_row2_col5" class="data row2 col5" >0.7581</td>
#       <td id="T_45b58_row2_col6" class="data row2 col6" >0.6099</td>
#       <td id="T_45b58_row2_col7" class="data row2 col7" >0.6138</td>
#       <td id="T_45b58_row2_col8" class="data row2 col8" >0.0170</td>
#     </tr>
#     <tr>
#       <th id="T_45b58_level0_row3" class="row_heading level0 row3" >gbc</th>
#       <td id="T_45b58_row3_col0" class="data row3 col0" >Gradient Boosting Classifier</td>
#       <td id="T_45b58_row3_col1" class="data row3 col1" >0.8037</td>
#       <td id="T_45b58_row3_col2" class="data row3 col2" >0.8888</td>
#       <td id="T_45b58_row3_col3" class="data row3 col3" >0.7499</td>
#       <td id="T_45b58_row3_col4" class="data row3 col4" >0.7545</td>
#       <td id="T_45b58_row3_col5" class="data row3 col5" >0.7476</td>
#       <td id="T_45b58_row3_col6" class="data row3 col6" >0.5877</td>
#       <td id="T_45b58_row3_col7" class="data row3 col7" >0.5926</td>
#       <td id="T_45b58_row3_col8" class="data row3 col8" >0.0310</td>
#     </tr>
#     <tr>
#       <th id="T_45b58_level0_row4" class="row_heading level0 row4" >catboost</th>
#       <td id="T_45b58_row4_col0" class="data row4 col0" >CatBoost Classifier</td>
#       <td id="T_45b58_row4_col1" class="data row4 col1" >0.7944</td>
#       <td id="T_45b58_row4_col2" class="data row4 col2" >0.8889</td>
#       <td id="T_45b58_row4_col3" class="data row4 col3" >0.7120</td>
#       <td id="T_45b58_row4_col4" class="data row4 col4" >0.7540</td>
#       <td id="T_45b58_row4_col5" class="data row4 col5" >0.7296</td>
#       <td id="T_45b58_row4_col6" class="data row4 col6" >0.5643</td>
#       <td id="T_45b58_row4_col7" class="data row4 col7" >0.5676</td>
#       <td id="T_45b58_row4_col8" class="data row4 col8" >0.1010</td>
#     </tr>
#     <tr>
#       <th id="T_45b58_level0_row5" class="row_heading level0 row5" >lightgbm</th>
#       <td id="T_45b58_row5_col0" class="data row5 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_45b58_row5_col1" class="data row5 col1" >0.7930</td>
#       <td id="T_45b58_row5_col2" cla
# Processing:   0%|          | 0/69 [00:00<?, ?it/s]
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…
# <style type="text/css">
# </style>
# <table id="T_fe7af">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fe7af_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_fe7af_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_fe7af_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_fe7af_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_fe7af_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_fe7af_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_fe7af_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_fe7af_level0_col7" class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fe7af_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_fe7af_row0_col0" class="data row0 col0" >Linear Discriminant Analysis</td>
#       <td id="T_fe7af_row0_col1" class="data row0 col1" >0.8380</td>
#       <td id="T_fe7af_row0_col2" class="data row0 col2" >0.9073</td>
#       <td id="T_fe7af_row0_col3" class="data row0 col3" >0.7680</td>
#       <td id="T_fe7af_row0_col4" class="data row0 col4" >0.8067</td>
#       <td id="T_fe7af_row0_col5" class="data row0 col5" >0.7869</td>
#       <td id="T_fe7af_row0_col6" class="data row0 col6" >0.6564</td>
#       <td id="T_fe7af_row0_col7" class="data row0 col7" >0.6569</td>
#     </tr>
#   </tbody>
# </table>
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=FastMemory(location=/tmp/joblib),
#           steps=[('label_encoding',
#                   TransformerWrapperWithInverse(exclude=None, include=None,
#                                                 transformer=LabelEncoder())),
#                  ('numerical_imputer',
#                   TransformerWrapper(exclude=None,
#                                      include=['Id', 'WeekofPurchase', 'StoreID',
#                                               'PriceCH', 'PriceMM', 'DiscCH',
#                                               'DiscMM', 'SpecialCH', 'SpecialMM',
#                                               'LoyalCH', 'SalePriceMM',
#                                               'SalePriceC...
#                                                                 drop_invariant=False,
#                                                                 handle_missing='return_nan',
#                                                                 handle_unknown='value',
#                                                                 mapping=[{'col': 'Store7',
#                                                                           'data_type': dtype('O'),
#                                                                           'mapping': No     0
#  Yes    1
#  NaN   -1
#  dtype: int64}],
#                                                                 return_df=True,
#                                                                 verbose=0))),
#                  ('trained_model',
#                   LinearDiscriminantAnalysis(covariance_estimator=None,
#                                              n_components=None, priors=None,
#                                              shrinkage=None, solver='svd',
#                                              store_covariance=False,
#                                              tol=0.0001))],
#           verbose=False),
#  'best_pipeline.pkl')
